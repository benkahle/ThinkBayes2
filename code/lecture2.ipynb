# %%
import thinkbayes2
import thinkplot

# %%
d6 = thinkbayes2.Pmf(range(1,7))

# %%
thinkplot.Hist(d6)

# %%
two = d6+d6

# %%
thinkplot.Hist(two)

# %%
thinkplot.Pmf(two)

# %%
thinkplot.Pdf(two)

# %%
three = two+d6
four = three+d6
five = four+d6

# %%
thinkplot.Pmf(three)
thinkplot.Pmf(four)
thinkplot.Pmf(five)

# %%
three.Mean()
# Out:
# 10.500000000000002

# %%
three.Var()
# Out:
# 8.749999999999998

# %%
Std(three)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8dd616221de9> in <module>()
# ----> 1 Std(three)
#
# NameError: name 'Std' is not defined

# %%
three.Prob(16)
# Out:
# 0.027777777777777776

# %%
four.ProbGreater(three)
# Out:
# 0.9999999999999998

# %%
three.Std()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-b2ad2750396e> in <module>()
# ----> 1 three.Std()
#
# AttributeError: 'Pmf' object has no attribute 'Std'

# %%
three.ProbGreater(15)
# Out:
# 0.046296296296296294

# %%
from thinkbayes2 import Suite

# %%
three.Pdf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d747a7535af> in <module>()
# ----> 1 three.Pdf()
#
# NameError: name 'three' is not defined

# %%
three
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-febe6995bad4> in <module>()
# ----> 1 three
#
# NameError: name 'three' is not defined

# %%
d6 = thinkbayes2.Pmf(range(1,7))

# %%
import thinkbayes2
import thinkplot

# %%
d6
# Out:
# Pmf({1: 0.16666666666666666, 2: 0.16666666666666666, 3: 0.16666666666666666, 4: 0.16666666666666666, 5: 0.16666666666666666, 6: 0.16666666666666666})

# %%
three = d6+d6+d6

# %%
three.Pdf()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-6d747a7535af> in <module>()
# ----> 1 three.Pdf()
#
# AttributeError: 'Pmf' object has no attribute 'Pdf'

# %%
thinkplot.Pdf(three)

# %%
threeCdf = three.MakeCdf()

# %%
thinkplot.Pdfs([three, threeCdf])

# %%
three2 = threeCdf.MakePmf()

# %%
three2 == three
# Out:
# False

# %%
thinkplot.Pdfs([three, three2])

# %%
thinkplot.Cdf(threeCdf)
# Out:
# {'xscale': 'linear', 'yscale': 'linear'}

# %%
Pmf.Max
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1444e0ea8c60> in <module>()
# ----> 1 Pmf.Max
#
# NameError: name 'Pmf' is not defined

# %%
maxCdf = three.Max(6)

# %%
thinkplot.Cdf(maxCdf)
# Out:
# {'xscale': 'linear', 'yscale': 'linear'}

# %%
maxCdf.Mean()
# Out:
# 14.233118540966814

# %%
from dice import Dice
d = {4:2, 6:6, 8:3, 10:2, 12:4, 20:4}
dice = Dice(d)

# %%
thinkplot.Hist(dice)

# %%
dice.Update(6)
# Out:
# 0.10039682539682537

# %%
dice
# Out:
# Dice({4: 0.09523809523809523, 6: 0.2857142857142857, 8: 0.14285714285714285, 10: 0.09523809523809523, 12: 0.19047619047619047, 20: 0.19047619047619047})

# %%
pmf = dice

# %%
pmf.update(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-dc8c0a2d4f1e> in <module>()
# ----> 1 pmf.update(6)
#
# AttributeError: 'Dice' object has no attribute 'update'

# %%
thinkplot.Hist(dice)

# %%
dice.Update(8)
# Out:
# 0.02991584518524093
